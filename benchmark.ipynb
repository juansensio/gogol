# %%
import pandas as pd

df = pd.read_csv('benchmark.csv')

df
# Out:
#     size algorithm  time_ms  iterations_per_second
# 0    100     naive       11                 9090.9
# 1    100    padded        7                14285.7
# 2    100  structed        9                11111.1
# 3    100    matrix        6                16666.7
# 4    200     naive       39                 2564.1
# 5    200    padded       30                 3333.3
# 6    200  structed       38                 2631.6
# 7    200    matrix       23                 4347.8
# 8    500     naive      246                  406.5
# 9    500    padded      195                  512.8
# 10   500  structed      245                  408.2
# 11   500    matrix      155                  645.2
# 12  1000     naive      976                  102.5
# 13  1000    padded      797                  125.5
# 14  1000  structed     1000                  100.0
# 15  1000    matrix      626                  159.7

# %%
df.pivot(index='size', columns='algorithm', values='iterations_per_second').plot(kind='line', marker='o', logy=True, grid=True)
# Out:
# <Axes: xlabel='size'>
