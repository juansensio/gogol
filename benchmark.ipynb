# %%
import pandas as pd

df = pd.read_csv('benchmark.csv')

df
# Out:
#     size   algorithm  time_ms  iterations_per_second
# 0    100  parallel_2        8                12500.0
# 1    100  parallel_4        5                20000.0
# 2    100  parallel_8        4                25000.0
# 3    200  parallel_2       24                 4166.7
# 4    200  parallel_4       14                 7142.9
# 5    200  parallel_8       13                 7692.3
# 6    500  parallel_2      142                  704.2
# 7    500  parallel_4       84                 1190.5
# 8    500  parallel_8       56                 1785.7
# 9   1000  parallel_2      567                  176.4
# 10  1000  parallel_4      319                  313.5
# 11  1000  parallel_8      197                  507.6

# %%
import pandas as pd

df = pd.read_csv('benchmark.csv')

df.pivot(index='size', columns='algorithm', values='iterations_per_second').plot(kind='line', marker='o', logy=True, grid=True)
# Out:
# <Axes: xlabel='size'>
